# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

# =====================================================
# ROOT CONFIG (CONVOLUTIONAL FMNIST)
# =====================================================
ROOT_DIR = r"C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100"

PRUNE_TYPES = [
    "prune_layers_ALL",
    "prune_layers_CONV",
    "prune_layers_FHL",
    "prune_layers_SHL",
    "prune_layers_FHL+SHL",
]

BATCH_DIR_TEMPLATE = "p-percentage_{}\\batch_size_{}"
FILE_PATTERN = "convol_{}_{}_run_*.txt"


BATCH_SIZES = [64, 1024]
PRUNING_LEVELS = [0.9,0.92,0.94,0.96,0.98, 1.0]
print(PRUNING_LEVELS)

PLOT_ROOT = os.path.join(ROOT_DIR, "plots")

# =====================================================
# STYLE (Nature-like)
# =====================================================
plt.rcParams.update({
    "font.size": 18,
    "axes.titlesize": 18,
    "axes.labelsize": 18,
    "xtick.labelsize": 18,
    "ytick.labelsize": 18,
    "legend.fontsize": 15
})

# =====================================================
# MAIN LOOP
# =====================================================
for prune_type in PRUNE_TYPES:

    print(f"\n=== Processing {prune_type} ===")

    BASE_DIR = os.path.join(ROOT_DIR, prune_type)
    PLOT_DIR = os.path.join(PLOT_ROOT, prune_type)
    os.makedirs(PLOT_DIR, exist_ok=True)
    

    for bs in BATCH_SIZES:
        all_avg_dfs = {}

        # ==============================================
        # LOAD + AVERAGE RUNS (ALL PRUNING LEVELS)
        # ==============================================
        for p in PRUNING_LEVELS:
            folder = os.path.join(BASE_DIR, BATCH_DIR_TEMPLATE.format(p, bs))
            files = glob.glob(os.path.join(folder, FILE_PATTERN.format(p, bs)))

            if not files:
                print(f"[WARNING] No files for {prune_type}, p={p}, bs={bs}")
                continue

            dfs = []
            for f in files:
                df = pd.read_csv(f, sep=r"\s+")
                df.columns = df.columns.str.strip()

                df["CE_Train"] = pd.to_numeric(df["CE_Train"], errors="coerce")
                df["CE_TEST"] = pd.to_numeric(df["CE_TEST"], errors="coerce")
                df["Accuracy(%)"] = pd.to_numeric(df["Accuracy(%)"], errors="coerce")

                dfs.append(df)

            all_runs = pd.concat(dfs, ignore_index=True)

            avg_df = all_runs.groupby("Batch_Number", as_index=False).agg(
                Avg_CE_Train=("CE_Train", "mean"),
                Avg_CE_Test=("CE_TEST", "mean"),
                Avg_Accuracy=("Accuracy(%)", "mean"),
                Num_Runs=("CE_TEST", "count")
            )

            # SAVE AVERAGED CSV
            avg_csv = os.path.join(folder, f"averaged_runs_p_{p}_bs_{bs}.csv")
            avg_df.to_csv(avg_csv, index=False)

            all_avg_dfs[p] = avg_df
            print(folder)

        # ==============================================
        # COMBINED PLOTS (ONE PER METRIC)
        # ==============================================
        def plot_metric(metric_col, ylabel, title_text, subtitle_text, filename, legend_loc, bbox):
            plt.figure(figsize=(12, 6))

            for p, df in all_avg_dfs.items():
                plt.plot(df["Batch_Number"], df[metric_col], label=f"P%={p}")

            plt.xlabel("Batch Number")
            plt.ylabel(ylabel)
            

            if metric_col == 'Avg_Accuracy':
                plt.text(0.5, 0.55, title_text, ha="center",
                     fontsize=16, transform=plt.gca().transAxes, va="top")
                plt.text(0.5, 0.50, subtitle_text, ha="center",
                     fontsize=16, transform=plt.gca().transAxes, va="top")

            else:
                plt.text(0.5, 0.95, title_text, ha="center",
                     transform=plt.gca().transAxes, va="top")
                plt.text(0.5, 0.90, subtitle_text, ha="center",
                     fontsize=16, transform=plt.gca().transAxes, va="top")

            handles, labels = plt.gca().get_legend_handles_labels()
            plt.legend(handles[::-1], labels[::-1],
                       loc=legend_loc, bbox_to_anchor=bbox, frameon=False)

            plt.grid(True)
            if metric_col in ["Avg_CE_Train", "Avg_CE_Test"]:
                plt.ylim(0, 2.5)

            plt.tight_layout()
            plt.savefig(os.path.join(PLOT_DIR, filename), dpi=300, bbox_inches="tight")
            plt.show()

        # ---- CE TRAIN ----
        pretty_prune = os.path.basename(prune_type).split("prune_layers_")[-1] # renaming the prune_type
        if pretty_prune == "ALL":
            pretty_prune = pretty_prune + "-Layers"
        # if pretty_prune == "CONV":
        #     pretty_prune == "CNN"
        
        
        plot_metric(
            metric_col="Avg_CE_Train",
            ylabel="Average CE",
            title_text="Cross-Entropy",
            subtitle_text=f"(CNN-{pretty_prune} FMNIST Training-Vectors, BS={bs})",
            filename=f"CE_Train_Avg_CONV_FMNIST_BS_{bs}.png",
            legend_loc="upper right",
            bbox=(1.0, 1.02)
        )

        # ---- CE TEST ----
        plot_metric(
            metric_col="Avg_CE_Test",
            ylabel="Average CE",
            title_text="Cross-Entropy",
            subtitle_text=f"(CNN-{pretty_prune} FMNIST Test-Vectors, BS={bs})",
            filename=f"CE_Test_Avg_CONV_FMNIST_BS_{bs}.png",
            legend_loc="upper right",
            bbox=(1.0, 1.02)
        )


        plot_metric(
            metric_col="Avg_Accuracy",
            ylabel="Average Accuracy",
            title_text="Accuracy",
            subtitle_text = f"(CNN-{pretty_prune} FMNIST Test-Vectors, BS={bs})",
            filename=f"Accuracy_Avg_CONV_FMNIST_BS_{bs}.png",
            legend_loc="lower right",
            bbox=(1.0, 0.1)
        )
# Out:
# [0.9, 0.92, 0.94, 0.96, 0.98, 1.0]
#
# === Processing prune_layers_ALL ===
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.9\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.92\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.94\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.96\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.98\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_1.0\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.9\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.92\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.94\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.96\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_0.98\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_ALL\p-percentage_1.0\batch_size_1024
# === Processing prune_layers_CONV ===
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.9\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.92\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.94\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.96\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.98\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_1.0\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.9\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.92\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.94\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.96\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_0.98\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_CONV\p-percentage_1.0\batch_size_1024
# === Processing prune_layers_FHL ===
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.9\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.92\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.94\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.96\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.98\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_1.0\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.9\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.92\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.94\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.96\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_0.98\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL\p-percentage_1.0\batch_size_1024
# === Processing prune_layers_SHL ===
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.9\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.92\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.94\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.96\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.98\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_1.0\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.9\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.92\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.94\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.96\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_0.98\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_SHL\p-percentage_1.0\batch_size_1024
# === Processing prune_layers_FHL+SHL ===
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.9\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.92\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.94\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.96\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.98\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_1.0\batch_size_64
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.9\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.92\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.94\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.96\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_0.98\batch_size_1024
# C:\Users\Student\Desktop\Neural_research\physlab\Convolution\Convolutional\Convolutional-FMNIST\TEST_90_100\prune_layers_FHL+SHL\p-percentage_1.0\batch_size_1024
